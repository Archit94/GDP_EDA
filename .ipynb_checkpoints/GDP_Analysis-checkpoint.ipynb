# %% [markdown]
# # Part-I: GDP Analysis of the Indian States
# ## Part I-A

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pylab as plt

# %%
df = pd.read_csv("./Statewise GDP.csv")
# finding the percentage null values in each row
row_null_perc = (df.isnull().sum(axis=1)/len(df.columns))*100
row_null_perc
# Out:
# 0      2.777778
# 1      2.777778
# 2      2.777778
# 3      2.777778
# 4     27.777778
# 5     63.888889
# 6      2.777778
# 7      2.777778
# 8      2.777778
# 9     27.777778
# 10    63.888889
# dtype: float64

# %% [markdown]
# <b>Remove the rows: '(% Growth over the previous year)' and 'GSDP - CURRENT PRICES (` in Crore)' for the year 2016-17</b>

# %%
# Since the % of missing values is very high in 2016-17 rows, we will drop them
df = df[row_null_perc < 60]
df
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# 3           16761.00  198098.00  373920.00     234982.00  40633.00  895027.00
# 4           18784.00  224234.00  413503.00     260776.00  45002.00  994316.00
# 6              13.41       9.56      14.25         12.30    -10.02      17.69
# 7              16.38      13.31      12.30         16.44     -5.77      11.47
# 8              14.79      11.45      17.92         13.69     13.12      10.82
# 9              12.07      13.19      10.59         10.98     10.75      11.09
#
#      Haryana  ...  Telangana   Tripura  Uttar Pradesh  Uttarakhand  \
# 0  297539.00  ...  359433.00  19208.00      724049.00    115523.00
# 1  347032.00  ...  401493.00  21663.00      822903.00    131835.00
# 2  400662.00  ...  452186.00  25593.00      944146.00    149817.00
# 3  437462.00  ...  511178.00  29667.00     1043371.00    161985.00
# 4  485184.00  ...  575631.00       NaN     1153795.00    184091.00
# 6      16.63  ...      11.70     12.78          13.65        14.12
# 7      15.45  ...      12.63     18.14          14.73        13.64
# 8       9.18  ...      13.05     15.92          10.51         8.12
# 9      10.91  ...      12.61       NaN          10.58        13.65
#
#    West Bengal1  Andaman & Nicobar Islands  Chandigarh      Delhi  Puducherry  \
# 0           NaN                    3979.00    18768.00  343767.00    16818.00
# 1           NaN                    4421.00    21609.00  391238.00    18875.00
# 2           NaN                    5159.00    24787.00  443783.00    21870.00
# 3           NaN                    5721.00    27844.00  492424.00    24089.00
# 4           NaN                        NaN    30304.00  551963.00    26533.00
# 6           NaN                      11.13       15.14      13.81       12.23
# 7           NaN                      16.68       14.71      13.43       15.87
# 8           NaN                      10.89       12.33      10.96       10.14
# 9           NaN                        NaN        8.84      12.09       10.15
#
#    All_India GDP
# 0     8736039.00
# 1     9946636.00
# 2    11236635.00
# 3    12433749.00
# 4    13675331.00
# 6          13.86
# 7          12.97
# 8          10.65
# 9           9.99
#
# [9 rows x 36 columns]

# %%
# finding columnwise null %
col_null_perc = (df.isnull().sum(axis=0)/len(df.index))*100
col_null_perc
# Out:
# Items  Description             0.000000
# Duration                       0.000000
# Andhra Pradesh                 0.000000
# Arunachal Pradesh              0.000000
# Assam                          0.000000
# Bihar                          0.000000
# Chhattisgarh                   0.000000
# Goa                            0.000000
# Gujarat                        0.000000
# Haryana                        0.000000
# Himachal Pradesh              22.222222
# Jammu & Kashmir                0.000000
# Jharkhand                      0.000000
# Karnataka                      0.000000
# Kerala                         0.000000
# Madhya Pradesh                 0.000000
# Maharashtra                   22.222222
# Manipur                       22.222222
# Meghalaya                      0.000000
# Mizoram                       22.222222
# Nagaland                      22.222222
# Odisha                         0.000000
# Punjab                        22.222222
# Rajasthan                     22.222222
# Sikkim                         0.000000
# Tamil Nadu                     0.000000
# Telangana                      0.000000
# Tripura                       22.222222
# Uttar Pradesh                  0.000000
# Uttarakhand                    0.000000
# West Bengal1                 100.000000
# Andaman & Nicobar Islands     22.222222
# Chandigarh                     0.000000
# Delhi                          0.000000
# Puducherry                     0.000000
# All_India GDP                  0.000000
# dtype: float64

# %%
# as we can see that for West Bengal, all are null values, we can drop that column
df=df.drop(['West Bengal1'],axis=1)
df
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# 3           16761.00  198098.00  373920.00     234982.00  40633.00  895027.00
# 4           18784.00  224234.00  413503.00     260776.00  45002.00  994316.00
# 6              13.41       9.56      14.25         12.30    -10.02      17.69
# 7              16.38      13.31      12.30         16.44     -5.77      11.47
# 8              14.79      11.45      17.92         13.69     13.12      10.82
# 9              12.07      13.19      10.59         10.98     10.75      11.09
#
#      Haryana  ...  Tamil Nadu  Telangana   Tripura  Uttar Pradesh  \
# 0  297539.00  ...   751485.00  359433.00  19208.00      724049.00
# 1  347032.00  ...   855481.00  401493.00  21663.00      822903.00
# 2  400662.00  ...   971090.00  452186.00  25593.00      944146.00
# 3  437462.00  ...  1092564.00  511178.00  29667.00     1043371.00
# 4  485184.00  ...  1212668.00  575631.00       NaN     1153795.00
# 6      16.63  ...       13.84      11.70     12.78          13.65
# 7      15.45  ...       13.51      12.63     18.14          14.73
# 8       9.18  ...       12.51      13.05     15.92          10.51
# 9      10.91  ...       10.99      12.61       NaN          10.58
#
#    Uttarakhand  Andaman & Nicobar Islands  Chandigarh      Delhi  Puducherry  \
# 0    115523.00                    3979.00    18768.00  343767.00    16818.00
# 1    131835.00                    4421.00    21609.00  391238.00    18875.00
# 2    149817.00                    5159.00    24787.00  443783.00    21870.00
# 3    161985.00                    5721.00    27844.00  492424.00    24089.00
# 4    184091.00                        NaN    30304.00  551963.00    26533.00
# 6        14.12                      11.13       15.14      13.81       12.23
# 7        13.64                      16.68       14.71      13.43       15.87
# 8         8.12                      10.89       12.33      10.96       10.14
# 9        13.65                        NaN        8.84      12.09       10.15
#
#    All_India GDP
# 0     8736039.00
# 1     9946636.00
# 2    11236635.00
# 3    12433749.00
# 4    13675331.00
# 6          13.86
# 7          12.97
# 8          10.65
# 9           9.99
#
# [9 rows x 35 columns]

# %% [markdown]
# <b>Calculate the average growth of states for the duration 2013-14, 2014-15 and 2015-16</b>

# %%
# we need to do analysis on only % Growth part so we can filter out the rows having 'GSDP - Current Prices'
df1=df[df['Items  Description'] == '(% Growth over previous year)']

# Dropping the Items Description column as it will have has same values
# Also dropping 2012-13 row
df1=df1.drop(['Items  Description'],axis=1)
df1=df1[df1.Duration != '2012-13']

# defining new row with avg values of % growth
#since some values are NaN, but we can't fill them with the avg of other states' GSDP or median, thus retaining them as it is 
df1.loc['avg_growth'] = df1.mean()
df1.loc['avg_growth','Duration']='avg_growth'
df1
# Out:
#               Duration  Andhra Pradesh   Arunachal Pradesh  Assam      Bihar  \
# 7              2013-14        12.850000          16.380000  13.31  12.300000
# 8              2014-15        13.400000          14.790000  11.45  17.920000
# 9              2015-16        15.850000          12.070000  13.19  10.590000
# avg_growth  avg_growth        14.033333          14.413333  12.65  13.603333
#
#             Chhattisgarh        Goa    Gujarat    Haryana  Himachal Pradesh  \
# 7              16.440000  -5.770000  11.470000  15.450000             14.42
# 8              13.690000  13.120000  10.820000   9.180000             10.14
# 9              10.980000  10.750000  11.090000  10.910000               NaN
# avg_growth     13.703333   6.033333  11.126667  11.846667             12.28
#
#             ...  Tamil Nadu  Telangana  Tripura  Uttar Pradesh  Uttarakhand  \
# 7           ...   13.510000  12.630000    18.14          14.73    13.640000
# 8           ...   12.510000  13.050000    15.92          10.51     8.120000
# 9           ...   10.990000  12.610000      NaN          10.58    13.650000
# avg_growth  ...   12.336667  12.763333    17.03          11.94    11.803333
#
#             Andaman & Nicobar Islands  Chandigarh  Delhi  Puducherry  \
# 7                              16.680       14.71  13.43   15.870000
# 8                              10.890       12.33  10.96   10.140000
# 9                                 NaN        8.84  12.09   10.150000
# avg_growth                     13.785       11.96  12.16   12.053333
#
#             All_India GDP
# 7               12.970000
# 8               10.650000
# 9                9.990000
# avg_growth      11.203333
#
# [4 rows x 34 columns]

# %%
# Transposing data and making first row as col headers
df_t=df1.T
head=df_t.iloc[0,:]
df_t=df_t.iloc[1:]
df_t.columns=head
df_t
# Out:
# Duration                  2013-14 2014-15 2015-16 avg_growth
# Andhra Pradesh              12.85    13.4   15.85    14.0333
# Arunachal Pradesh           16.38   14.79   12.07    14.4133
# Assam                       13.31   11.45   13.19      12.65
# Bihar                        12.3   17.92   10.59    13.6033
# Chhattisgarh                16.44   13.69   10.98    13.7033
# Goa                         -5.77   13.12   10.75    6.03333
# Gujarat                     11.47   10.82   11.09    11.1267
# Haryana                     15.45    9.18   10.91    11.8467
# Himachal Pradesh            14.42   10.14     NaN      12.28
# Jammu & Kashmir             10.09     4.7   17.91       10.9
# Jharkhand                    7.92   15.14   11.44       11.5
# Karnataka                   18.24    12.7   11.42      14.12
# Kerala                      12.79   13.11   11.85    12.5833
# Madhya Pradesh              14.91   10.11   12.86    12.6267
# Maharashtra                 13.74    8.78     NaN      11.26
# Manipur                     17.83   11.39     NaN      14.61
# Meghalaya                    4.87    6.41    9.58    6.95333
# Mizoram                      23.1    12.3     NaN       17.7
# Nagaland                    21.98   10.85     NaN     16.415
# Odisha                      12.95   10.37    6.19    9.83667
# Punjab                      12.42    9.95     NaN     11.185
# Rajasthan                   11.27   11.37     NaN      11.32
# Sikkim                      12.35    9.72    9.39    10.4867
# Tamil Nadu                  13.51   12.51   10.99    12.3367
# Telangana                   12.63   13.05   12.61    12.7633
# Tripura                     18.14   15.92     NaN      17.03
# Uttar Pradesh               14.73   10.51   10.58      11.94
# Uttarakhand                 13.64    8.12   13.65    11.8033
# Andaman & Nicobar Islands   16.68   10.89     NaN     13.785
# Chandigarh                  14.71   12.33    8.84      11.96
# Delhi                       13.43   10.96   12.09      12.16
# Puducherry                  15.87   10.14   10.15    12.0533
# All_India GDP               12.97   10.65    9.99    11.2033

# %%
#sorting dataframe on basis of avg_growth 
df_t=df_t.sort_values(['avg_growth'])
df_t
# Out:
# Duration                  2013-14 2014-15 2015-16 avg_growth
# Goa                         -5.77   13.12   10.75    6.03333
# Meghalaya                    4.87    6.41    9.58    6.95333
# Odisha                      12.95   10.37    6.19    9.83667
# Sikkim                      12.35    9.72    9.39    10.4867
# Jammu & Kashmir             10.09     4.7   17.91       10.9
# Gujarat                     11.47   10.82   11.09    11.1267
# Punjab                      12.42    9.95     NaN     11.185
# All_India GDP               12.97   10.65    9.99    11.2033
# Maharashtra                 13.74    8.78     NaN      11.26
# Rajasthan                   11.27   11.37     NaN      11.32
# Jharkhand                    7.92   15.14   11.44       11.5
# Uttarakhand                 13.64    8.12   13.65    11.8033
# Haryana                     15.45    9.18   10.91    11.8467
# Uttar Pradesh               14.73   10.51   10.58      11.94
# Chandigarh                  14.71   12.33    8.84      11.96
# Puducherry                  15.87   10.14   10.15    12.0533
# Delhi                       13.43   10.96   12.09      12.16
# Himachal Pradesh            14.42   10.14     NaN      12.28
# Tamil Nadu                  13.51   12.51   10.99    12.3367
# Kerala                      12.79   13.11   11.85    12.5833
# Madhya Pradesh              14.91   10.11   12.86    12.6267
# Assam                       13.31   11.45   13.19      12.65
# Telangana                   12.63   13.05   12.61    12.7633
# Bihar                        12.3   17.92   10.59    13.6033
# Chhattisgarh                16.44   13.69   10.98    13.7033
# Andaman & Nicobar Islands   16.68   10.89     NaN     13.785
# Andhra Pradesh              12.85    13.4   15.85    14.0333
# Karnataka                   18.24    12.7   11.42      14.12
# Arunachal Pradesh           16.38   14.79   12.07    14.4133
# Manipur                     17.83   11.39     NaN      14.61
# Nagaland                    21.98   10.85     NaN     16.415
# Tripura                     18.14   15.92     NaN      17.03
# Mizoram                      23.1    12.3     NaN       17.7

# %% [markdown]
# <b> Plot avg growth for the states</b>

# %%
# plotting graph
# since there are many states we can take them on y-axis
plt.figure(figsize=(12,12))
bp=sns.barplot(df_t.avg_growth,df_t.index)
bp.set_title("Avg Growth of States' GSDP")
plt.savefig('avg_growth.png')
plt.show()

# %%
# We can see from above that north eastern states have fairly high rate of growth, except sikkim and meghalaya which alongwith
# odisha, goa are relatively growing very slow

# My home state UP is above avg. of All India GDP

# %% [markdown]
# <b>Plot the total GDP of the states for the year 2015-16</b>

# %%
# Getting total GSDP for year 2015-16
df2=df[(df['Items  Description'] != '(% Growth over previous year)') & (df['Duration'] == '2015-16')]

# transposing data to get data for graph
df2=df2.T

# modifying column names
header=df2.iloc[0,]
header.iloc[0]='GSDP(crore)'
df2=df2.iloc[2:,]
df2.columns=header

# sorting on basis of GSDP and dropping NA values
df2=df2.sort_values(df2.columns[0])
df2.dropna(inplace=True)

# plotting graph for GSDP of states in log scale (as values vary on a large scale)
plt.figure(figsize=(12,12))
bp2=sns.barplot(df2['GSDP'],df2.index)
bp2.set_title("GSDP of States")
bp2.set_xscale('log')
plt.savefig('GSDP.png')
plt.show()

# %%
# We can see that 5 highest GDP states are as follows:
# 1.Tamil Nadu
# 2.UP
# 3.Karnataka
# 4.Gujarat
# 5.Andhra Pradesh

# Bottom-5 consist 2 Union Territories
# 1.Sikkim
# 2.Arunachal Pradesh
# 3.Puducherry
# 4.Meghalaya
# 5.Chandigarh

# %% [markdown]
# # -----------------------------------------------------------------------------------------------------------
# ## END
# # -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Part I-B

# %%
# Reading files list using glob
import glob
filenames = glob.glob("./NAD*.csv")
l=[]
print(filenames)
# Out:
# ['.\\NAD-Andaman_Nicobar_Islands-GSVA_cur_2014-15.csv', '.\\NAD-Andhra_Pradesh-GSVA_cur_2016-17.csv', '.\\NAD-Arunachal_Pradesh-GSVA_cur_2015-16.csv', '.\\NAD-Assam-GSVA_cur_2015-16.csv', '.\\NAD-Bihar-GSVA_cur_2015-16.csv', '.\\NAD-Chandigarh-GSVA_cur_2015-16.csv', '.\\NAD-Chhattisgarh-GSVA_cur_2016-17.csv', '.\\NAD-Delhi-GSVA_cur_2016-17.csv', '.\\NAD-Goa-GSVA_cur_2015-16.csv', '.\\NAD-Gujarat-GSVA_cur_2015-16.csv', '.\\NAD-Haryana-GSVA_cur_2016-17.csv', '.\\NAD-Himachal_Pradesh-GSVA_cur_2014-15.csv', '.\\NAD-Jammu_Kashmir-GSVA_cur_2015-16.csv', '.\\NAD-Jharkhand-GSVA_cur_2015-16.csv', '.\\NAD-Karnataka-GSVA_cur_2015-16.csv', '.\\NAD-Kerala-GSVA_cur_2015-16.csv', '.\\NAD-Madhya_Pradesh-GSVA_cur_2016-17.csv', '.\\NAD-Maharashtra-GSVA_cur_2014-15.csv', '.\\NAD-Manipur-GSVA_cur_2014-15.csv', '.\\NAD-Meghalaya-GSVA_cur_2016-17.csv', '.\\NAD-Mizoram-GSVA_cur_2014-15.csv', '.\\NAD-Nagaland-GSVA_cur_2014-15.csv', '.\\NAD-Odisha-GSVA_cur_2016-17.csv', '.\\NAD-Puducherry-GSVA_cur_2016-17.csv', '.\\NAD-Punjab-GSVA_cur_2014-15.csv', '.\\NAD-Rajasthan-GSVA_cur_2014-15.csv', '.\\NAD-Sikkim-GSVA_cur_2015-16.csv', '.\\NAD-Tamil_Nadu-GSVA_cur_2016-17.csv', '.\\NAD-Telangana-GSVA_cur_2016-17.csv', '.\\NAD-Tripura-GSVA_cur_2014-15.csv', '.\\NAD-Uttarakhand-GSVA_cur_2015-16.csv', '.\\NAD-Uttar_Pradesh-GSVA_cur_2015-16.csv']

# %% [markdown]
# <b>Reading many dataframes and combining</b>

# %%
# combining all files in a single dataframe
for i in filenames:
    data = pd.read_csv(i,encoding='latin_1')
    # extracting only Item and 2014-15 columns
    data = data[['Item','2014-15']]
    
    # since some data  has * at the end, removing same for resolving conflict during merging
    data['Item']=data['Item'].map(lambda x: x.rstrip('*'))
    # taking transposed data and making first row as header in new dataframe
    data = data.T
    head = data.iloc[0]
    data = data.iloc[1:]
    data.columns = head
    
    # adding state column and making it the first column
    data['State'] = i.split('-')[1]
    col = data.columns.tolist()[-1:] + data.columns.tolist()[:-1]
    data = data[col]
    l.append(data)

# final dataframe has all the previous dataframes combined
final_df = pd.concat(l, axis=0,sort=False,ignore_index=True)
final_df
# Out:
# Item                    State Agriculture, forestry and fishing        Crops  \
# 0     Andaman_Nicobar_Islands                             76670        34026
# 1              Andhra_Pradesh                          14819416      7893514
# 2           Arunachal_Pradesh                            686117       415520
# 3                       Assam                           3855548      2890544
# 4                       Bihar                           7951890      4688237
# 5                  Chandigarh                             16233         1659
# 6                Chhattisgarh                           3948847      2613371
# 7                       Delhi                            250568        64959
# 8                         Goa                            308507       140421
# 9                     Gujarat                         1.377e+07  9.67109e+06
# 10                    Haryana                       8.01524e+06  4.63673e+06
# 11           Himachal_Pradesh                           1514981       853758
# 12              Jammu_Kashmir                           1586705       949424
# 13                  Jharkhand                           3211065      2094466
# 14                  Karnataka                          11219422      8157179
# 15                     Kerala                           5930617      3070386
# 16             Madhya_Pradesh                          16235647     13216013
# 17                Maharashtra                          16475655     10435121
# 18                    Manipur                            383140       226583
# 19                  Meghalaya                            366521       223330
# 20                    Mizoram                            217010       116609
# 21                   Nagaland                            607897       375825
# 22                     Odisha                           6422978      4382636
# 23                 Puducherry                            113156        38878
# 24                     Punjab                           9285716      5690972
# 25                  Rajasthan                          15044394      7673441
# 26                     Sikkim                            137447       114976
# 27                 Tamil_Nadu                          13064238      7297820
# 28                  Telangana                           7591501      4162493
# 29                    Tripura                            799825       397591
# 30                Uttarakhand                       1.60142e+06       866146
# 31              Uttar_Pradesh                          25097754     16215212
#
# Item    Livestock Forestry and logging Fishing and aquaculture  \
# 0           19560                 4634                   18451
# 1         4309078               346160                 2270664
# 2           38387               224017                    8193
# 3          173478               261987                  529539
# 4         2060296               550132                  653224
# 5           13992                  388                     194
# 6          352208               597785                  385483
# 7          183770                  861                     978
# 8           30141                15744                  122201
# 9     2.69891e+06               761616                  638357
# 10    2.91617e+06               352254                  110080
# 11         110304               540950                    9968
# 12         433133               168093                   36055
# 13         562503               445149                  108947
# 14        1868771               693082                  500390
# 15        1656104               499808                  704319
# 16        1932769               965588                  121277
# 17        3972829              1592564                  475141
# 18          75483                45831                   35243
# 19          72442                61166                    9583
# 20          45590                47763                    7048
# 21         123800                99802                    8470
# 22         788243               791463                  460636
# 23          45358                 3931                   24989
# 24        2638842               848245                  107657
# 25        5356257              1956660                   58036
# 26          17338                 4529                     604
# 27        4693361               392705                  680352
# 28        2951299               210741                  266968
# 29          88176               145096                  168961
# 30         391188               339293                    4796
# 31        7096876              1404936                  380730
#
# Item Mining and quarrying      Primary Manufacturing  \
# 0                   18738        95409          6650
# 1                 1484300     16303716       4672266
# 2                   30842       716959         26120
# 3                 1471149      5326697       2002936
# 4                   68107      8019997       2189965
# 5                     179        16412        149631
# 6                 2451970      6400817       4370593
# 7                  963777      1214345       2749307
# 8                    3622       312129       1177608
# 9             2.11722e+06  1.58872e+07   2.40875e+07
# 10                  25186  8.04042e+06   7.75692e+06
# 11                  33385      1548366       2543637
# 12                  33621      1620326        893207
# 13                2037289      5248354       4114148
# 14                 846882     12066304      12953843
# 15                 558824      6489442       4273567
# 16                1618373     17854020       4368833
# 17                5282727     21758383      33660294
# 18                    NaN       383140         49501
# 19                  84529       451050        433213
# 20                   8588       225598          8479
# 21                   8280       616178         18346
# 22                2586328      9009306       5754229
# 23                  33272       146428        618297
# 24                  10354      9296070       4790341
# 25                4069385     19113780       6552580
# 26                   1329       138776        550697
# 27                 265536     13329774      18914794
# 28                1541853      9133354       6353711
# 29                 142391       942216        228625
# 30                 244549  1.84597e+06   5.86625e+06
# 31                 901501     25999255      12261649
#
# Item Electricity, gas, water supply & other utility services  ...  \
# 0                                                 30607       ...
# 1                                               1151729       ...
# 2                                                113527       ...
# 3                                                296587       ...
# 4                                                345168       ...
# 5                                                 29741       ...
# 6                                               1198438       ...
# 7                                                971255       ...
# 8                                                204110       ...
# 9                                           3.40998e+06       ...
# 10                                          1.10192e+06       ...
# 11                                               767268       ...
# 12                                               597421       ...
# 13                                               337489       ...
# 14                                              1425762       ...
# 15                                               482470       ...
# 16                                              1272905       ...
# 17                                              4334702       ...
# 18                                                27490       ...
# 19                                                54473       ...
# 20                                               128365       ...
# 21                                                37944       ...
# 22                                               833067       ...
# 23                                                60624       ...
# 24                                               911611       ...
# 25                                              1122888       ...
# 26                                               212499       ...
# 27                                              1710379       ...
# 28                                               716266       ...
# 29                                                77870       ...
# 30                                               433880       ...
# 31                                              2030625       ...
#
# Item Real estate, ownership of dwelling & professional services  \
# 0                                                 45499
# 1                                               4405409
# 2                                                 48418
# 3                                               1412466
# 4                                               3740641
# 5                                                598448
# 6                                               2462166
# 7                                              11733335
# 8                                                407099
# 9                                            5.1795e+06
# 10                                          6.97018e+06
# 11                                              1125937
# 12                                              1340082
# 13                                              1656784
# 14                                             24766393
# 15                                              7287633
# 16                                              2660123
# 17                                             30718051
# 18                                               159335
# 19                                               150409
# 20                                                55068
# 21                                               159651
# 22                                              2348714
# 23                                               251106
# 24                                              3142786
# 25                                              6451997
# 26                                                75330
# 27                                             16830213
# 28                                              9478839
# 29                                               190704
# 30                                               831307
# 31                                             14548185
#
# Item Public administration Other services     Tertiary  \
# 0                    97359          90292       372538
# 1                  2200897        4215389     22032942
# 2                   243867         218728       631844
# 3                  1373611        1795658      9307109
# 4                  2078171        4587589     22179969
# 5                   183889         156543      2426008
# 6                   867982        1112232      7588778
# 7                  2008191        3829385     36039554
# 8                   346486         180431      1738217
# 9               2.5762e+06    3.12341e+06  3.02204e+07
# 10             1.03638e+06    2.00158e+06  1.92266e+07
# 11                  553974         923164      4133326
# 12                 1349880         946826      5613282
# 13                 1088325        1375410      8133341
# 14                 2232584        5308174     50490630
# 15                 2068915        5728645     29673778
# 16                 2497321        2747805     18117360
# 17                 5426991       10806363     88631076
# 18                  297078         317930  1.17733e+06
# 19                  239782         214211  1.20066e+06
# 20                  206259         186222       637619
# 21                  295424         259186       992956
# 22                 1318221        2340603     12256258
# 23                   82612         283268       977720
# 24                 1842730        3303041     16717805
# 25                 2460364        4164287     26015812
# 26                  119514         149265       483103
# 27                 3400800        7430115     53343788
# 28                 1711265        4158229     28471410
# 29                  338244         323287  1.48471e+06
# 30                  579409         982430  5.58798e+06
# 31                 6152124        5034623     45968959
#
# Item TOTAL GSVA at basic prices Taxes on Products Subsidies on products  \
# 0                        574506             11504                 13916
# 1                      48825542           5512100               1690800
# 2                       1636292             70099                 30272
# 3                      18666897           1725309                582406
# 4                      36184863           3213546               2006421
# 5                       2755113             52622                 23309
# 6                      22228481           2601791               1332092
# 7                      43023249           6611719                392546
# 8                       3597882            527279                 61854
# 9                   7.91311e+07       1.23532e+07           1.98155e+06
# 10                  3.98284e+07       4.98567e+06           1.06787e+06
# 11                      9800853            895317                259291
# 12                      9509739            764270                233563
# 13                     19623166           2499171                411619
# 14                     83041338          11026674               1889206
# 15                     48233259           5189352                822381
# 16                     46016269           4284700               2102800
# 17                    157834665          25394800               4017300
# 18                  1.78065e+06             92766                 69137
# 19                  2.28965e+06            213272                 62112
# 20                      1133289             43084                 20440
# 21                      1821495             57674                 37745
# 22                     30255256           3151184               1209349
# 23                      2119274            331269                 41686
# 24                     33918789           3794100                911800
# 25                     58158386           5394503               2333442
# 26                      1467133             72200                 18400
# 27                     99515453          12507325               2766405
# 28                     47528765           4425700                836700
# 29                  2.91132e+06            149345                 94002
# 30                  1.50768e+07       1.43486e+06                313139
# 31                     97516938          10107396               3287219
#
# Item Gross State Domestic Product Population ('00) Per Capita GSDP (Rs.)
# 0                          572094             4120                138858
# 1                        52646842           501510                104977
# 2                         1676119            14870                112718
# 3                        19809800           326780                 60621
# 4                        37391988          1101240                 33954
# 5                         2784426            11120                250398
# 6                        23498180           270530                 86860
# 7                        49242422           179690                274041
# 8                         4063307            14950                271793
# 9                     8.95027e+07           633590                141263
# 10                    4.37462e+07           266620                164077
# 11                       10436879            70840                147330
# 12                       10040446           132390                 75840
# 13                       21710718           349660                 62091
# 14                       92178806           635100                145141
# 15                       52600230           339843                154778
# 16                       48198169           765180                 62989
# 17                      179212165          1172450                152853
# 18                    1.80428e+06            30873                 58442
# 19                    2.44081e+06            32020                 76228
# 20                        1155933            11833                 97687
# 21                        1841424            20550                 89607
# 22                       32197092           435220                 73979
# 23                        2408857            13710                175701
# 24                       36801089           290673                126606
# 25                       61219447           721610                 84837
# 26                        1520933             6330                240274
# 27                      109256373           745760                146503
# 28                       51117765           367660                139035
# 29                    2.96666e+06            38350                 77358
# 30                    1.61985e+07           105820                153076
# 31                      104337115          2109940                 49450
#
# [32 rows x 34 columns]

# %% [markdown]
# <b>Removing Union Territories</b>

# %%
# removing the union territories
UT=['Andaman_Nicobar_Islands','Puducherry','Chandigarh','Delhi']
final_df=final_df[~final_df.State.isin(UT)]
final_df.State
# Out:
# 1        Andhra_Pradesh
# 2     Arunachal_Pradesh
# 3                 Assam
# 4                 Bihar
# 6          Chhattisgarh
# 8                   Goa
# 9               Gujarat
# 10              Haryana
# 11     Himachal_Pradesh
# 12        Jammu_Kashmir
# 13            Jharkhand
# 14            Karnataka
# 15               Kerala
# 16       Madhya_Pradesh
# 17          Maharashtra
# 18              Manipur
# 19            Meghalaya
# 20              Mizoram
# 21             Nagaland
# 22               Odisha
# 24               Punjab
# 25            Rajasthan
# 26               Sikkim
# 27           Tamil_Nadu
# 28            Telangana
# 29              Tripura
# 30          Uttarakhand
# 31        Uttar_Pradesh
# Name: State, dtype: object

# %% [markdown]
# <b>Plotting the GDP per capita for all the states</b>

# %%
# plotting per capita gsdp
final_df1=final_df.sort_values(['Per Capita GSDP (Rs.)'] )
plt.figure(figsize=(12,12))
bar_p=sns.barplot(final_df1['Per Capita GSDP (Rs.)'],final_df1.State)
bar_p.set_title("Per capita GDP of States")
plt.savefig('Per_capita_GDP.png')
plt.show()

# %%
# From above Graph,
# Top 5 states: Goa, Sikkim, Haryana, Kerala, Uttarakhand
# Reasons can be attributed to lower population but high gsdp
# Bottom 5 states: Bihar, Uttar Pradesh, Manipur, Assam, Jharkhand
# For these, one main reason is high population which is unskilled and other is lack of production industries

# %%
# finding ratio of max/min per capita GDP
rat = final_df1['Per Capita GSDP (Rs.)'].max()/final_df1['Per Capita GSDP (Rs.)'].min()
print(rat)
# Out:
# 8.004741709371503

# %%
# The ratio of highest and lowest per capita GDP of states is very high indicating the irregular distribution
# of talent, money and administration in different parts of India

# %%
final_df1.columns
# Out:
# Index(['State', 'Agriculture, forestry and fishing', 'Crops', 'Livestock',
#        'Forestry and logging', 'Fishing and aquaculture',
#        'Mining and quarrying', 'Primary', 'Manufacturing',
#        'Electricity, gas, water supply & other utility services',
#        'Construction', 'Secondary', 'Trade, repair, hotels and restaurants',
#        'Trade & repair services', 'Hotels & restaurants',
#        'Transport, storage, communication & services related to broadcasting',
#        'Railways', 'Road transport', 'Water transport', 'Air transport',
#        'Services incidental to transport', 'Storage',
#        'Communication & services related to broadcasting',
#        'Financial services',
#        'Real estate, ownership of dwelling & professional services',
#        'Public administration', 'Other services', 'Tertiary',
#        'TOTAL GSVA at basic prices', 'Taxes on Products',
#        'Subsidies on products', 'Gross State Domestic Product',
#        'Population ('00)', 'Per Capita GSDP (Rs.)'],
#       dtype='object', name='Item')

# %% [markdown]
# <b>Plotting the percentage contribution of the primary, secondary and tertiary sectors as a percentage of the total GDP</b>

# %%
# Making new columns for % contribution of sectors
final_df1['Primary_perc']=final_df1['Primary']/final_df1['TOTAL GSVA at basic prices'] *100
final_df1['Secondary_perc']=final_df1['Secondary']/final_df1['TOTAL GSVA at basic prices'] *100
final_df1['Tertiary_perc']=final_df1['Tertiary']/final_df1['TOTAL GSVA at basic prices'] *100
final_df1['Misc_perc']=100-(final_df1['Tertiary_perc']+final_df1['Secondary_perc']+final_df1['Primary_perc'])

# plot
barWidth = 0.85
plt.figure(figsize=(40,20))
# Draw Primary Bars
plt.bar(np.arange(len(final_df1.index)), final_df1.Primary_perc, color='#b5ffb9', edgecolor='white', width=barWidth,label="Primary %")
# Draw Secondary Bars
plt.bar(np.arange(len(final_df1.index)), final_df1.Secondary_perc, bottom=final_df1.Primary_perc, color='#f9bc86', edgecolor='white'\
        , width=barWidth,label="Secondary %")
# Draw Tertiary Bars
plt.bar(np.arange(len(final_df1.index)), final_df1.Tertiary_perc, bottom=[i+j for i,j in zip(final_df1.Secondary_perc,\
            final_df1.Primary_perc)], color='#a3acff', edgecolor='white', width=barWidth,label="Tertiary %")
 
# Change the name of x axis
plt.xticks(np.arange(len(final_df1.index)),final_df1.State)
plt.xlabel("% wise contribution of sectors")
plt.legend(loc='upper left', bbox_to_anchor=(1,1), ncol=1)
# Show the graph
plt.savefig('perc_sector.png')
plt.show()

# %%
# We can see that for high per capita GDP states, majority of sector is Secondary and Tertiary
# Primary consists of the least percentage.
# Whereas for less GSDP per capita states, agriculture comes out to be 1st or 2nd high contributing sector, 
# whereas Secondary sector contribution is very less

# %% [markdown]
# <b>Categorise the states into four groups based on the GDP per capita</b>

# %%
# getting quantiles for specified quantile values
q1,q2,q3,q4=final_df1['Per Capita GSDP (Rs.)'].quantile([0.20, 0.5, 0.85, 1])
print(q1,q2,q3,q4)
# Out:
# 67385.0 101332.0 153064.85 271793.0

# %%
# function to categorize states in C1..C4

def categorize(x):
    if(x<=q1):
        return 'C4'
    if(x<=q2 and x>q1):
        return 'C3'
    if(x<=q3 and x>q2):
        return 'C2'
    if(x>q3):
        return 'C1'

#applying categorize function to create a category column

final_df1['Category'] = final_df1['Per Capita GSDP (Rs.)'].apply(categorize)

# %%
final_df1
# Out:
# Item              State Agriculture, forestry and fishing        Crops  \
# 4                 Bihar                           7951890      4688237
# 31        Uttar_Pradesh                          25097754     16215212
# 18              Manipur                            383140       226583
# 3                 Assam                           3855548      2890544
# 13            Jharkhand                           3211065      2094466
# 16       Madhya_Pradesh                          16235647     13216013
# 22               Odisha                           6422978      4382636
# 12        Jammu_Kashmir                           1586705       949424
# 19            Meghalaya                            366521       223330
# 29              Tripura                            799825       397591
# 25            Rajasthan                          15044394      7673441
# 6          Chhattisgarh                           3948847      2613371
# 21             Nagaland                            607897       375825
# 20              Mizoram                            217010       116609
# 1        Andhra_Pradesh                          14819416      7893514
# 2     Arunachal_Pradesh                            686117       415520
# 24               Punjab                           9285716      5690972
# 28            Telangana                           7591501      4162493
# 9               Gujarat                         1.377e+07  9.67109e+06
# 14            Karnataka                          11219422      8157179
# 27           Tamil_Nadu                          13064238      7297820
# 11     Himachal_Pradesh                           1514981       853758
# 17          Maharashtra                          16475655     10435121
# 30          Uttarakhand                       1.60142e+06       866146
# 15               Kerala                           5930617      3070386
# 10              Haryana                       8.01524e+06  4.63673e+06
# 26               Sikkim                            137447       114976
# 8                   Goa                            308507       140421
#
# Item    Livestock Forestry and logging Fishing and aquaculture  \
# 4         2060296               550132                  653224
# 31        7096876              1404936                  380730
# 18          75483                45831                   35243
# 3          173478               261987                  529539
# 13         562503               445149                  108947
# 16        1932769               965588                  121277
# 22         788243               791463                  460636
# 12         433133               168093                   36055
# 19          72442                61166                    9583
# 29          88176               145096                  168961
# 25        5356257              1956660                   58036
# 6          352208               597785                  385483
# 21         123800                99802                    8470
# 20          45590                47763                    7048
# 1         4309078               346160                 2270664
# 2           38387               224017                    8193
# 24        2638842               848245                  107657
# 28        2951299               210741                  266968
# 9     2.69891e+06               761616                  638357
# 14        1868771               693082                  500390
# 27        4693361               392705                  680352
# 11         110304               540950                    9968
# 17        3972829              1592564                  475141
# 30         391188               339293                    4796
# 15        1656104               499808                  704319
# 10    2.91617e+06               352254                  110080
# 26          17338                 4529                     604
# 8           30141                15744                  122201
#
# Item Mining and quarrying      Primary Manufacturing  \
# 4                   68107      8019997       2189965
# 31                 901501     25999255      12261649
# 18                    NaN       383140         49501
# 3                 1471149      5326697       2002936
# 13                2037289      5248354       4114148
# 16                1618373     17854020       4368833
# 22                2586328      9009306       5754229
# 12                  33621      1620326        893207
# 19                  84529       451050        433213
# 29                 142391       942216        228625
# 25                4069385     19113780       6552580
# 6                 2451970      6400817       4370593
# 21                   8280       616178         18346
# 20                   8588       225598          8479
# 1                 1484300     16303716       4672266
# 2                   30842       716959         26120
# 24                  10354      9296070       4790341
# 28                1541853      9133354       6353711
# 9             2.11722e+06  1.58872e+07   2.40875e+07
# 14                 846882     12066304      12953843
# 27                 265536     13329774      18914794
# 11                  33385      1548366       2543637
# 17                5282727     21758383      33660294
# 30                 244549  1.84597e+06   5.86625e+06
# 15                 558824      6489442       4273567
# 10                  25186  8.04042e+06   7.75692e+06
# 26                   1329       138776        550697
# 8                    3622       312129       1177608
#
# Item Electricity, gas, water supply & other utility services  ...  \
# 4                                                345168       ...
# 31                                              2030625       ...
# 18                                                27490       ...
# 3                                                296587       ...
# 13                                               337489       ...
# 16                                              1272905       ...
# 22                                               833067       ...
# 12                                               597421       ...
# 19                                                54473       ...
# 29                                                77870       ...
# 25                                              1122888       ...
# 6                                               1198438       ...
# 21                                                37944       ...
# 20                                               128365       ...
# 1                                               1151729       ...
# 2                                                113527       ...
# 24                                               911611       ...
# 28                                               716266       ...
# 9                                           3.40998e+06       ...
# 14                                              1425762       ...
# 27                                              1710379       ...
# 11                                               767268       ...
# 17                                              4334702       ...
# 30                                               433880       ...
# 15                                               482470       ...
# 10                                          1.10192e+06       ...
# 26                                               212499       ...
# 8                                                204110       ...
#
# Item Taxes on Products Subsidies on products Gross State Domestic Product  \
# 4              3213546               2006421                     37391988
# 31            10107396               3287219                    104337115
# 18               92766                 69137                  1.80428e+06
# 3              1725309                582406                     19809800
# 13             2499171                411619                     21710718
# 16             4284700               2102800                     48198169
# 22             3151184               1209349                     32197092
# 12              764270                233563                     10040446
# 19              213272                 62112                  2.44081e+06
# 29              149345                 94002                  2.96666e+06
# 25             5394503               2333442                     61219447
# 6              2601791               1332092                     23498180
# 21               57674                 37745                      1841424
# 20               43084                 20440                      1155933
# 1              5512100               1690800                     52646842
# 2                70099                 30272                      1676119
# 24             3794100                911800                     36801089
# 28             4425700                836700                     51117765
# 9          1.23532e+07           1.98155e+06                  8.95027e+07
# 14            11026674               1889206                     92178806
# 27            12507325               2766405                    109256373
# 11              895317                259291                     10436879
# 17            25394800               4017300                    179212165
# 30         1.43486e+06                313139                  1.61985e+07
# 15             5189352                822381                     52600230
# 10         4.98567e+06           1.06787e+06                  4.37462e+07
# 26               72200                 18400                      1520933
# 8               527279                 61854                      4063307
#
# Item Population ('00) Per Capita GSDP (Rs.) Primary_perc Secondary_perc  \
# 4             1101240                 33954       22.164        16.5398
# 31            2109940                 49450      26.6613        26.1993
# 18              30873                 58442      21.5169        12.3648
# 3              326780                 60621      28.5355        21.6056
# 13             349660                 62091      26.7457        31.8066
# 16             765180                 62989      38.7994         21.829
# 22             435220                 73979      29.7777        29.7128
# 12             132390                 75840      17.0386        23.9347
# 19              32020                 76228      19.6995         27.862
# 29              38350                 77358      32.3639        16.6383
# 25             721610                 84837       32.865        22.4023
# 6              270530                 86860      28.7956        37.0645
# 21              20550                 89607      33.8281        11.6586
# 20              11833                 97687      19.9065        23.8308
# 1              501510                104977      33.3918        21.4824
# 2               14870                112718      43.8161        17.5695
# 24             290673                126606      27.4068        23.3054
# 28             367660                139035      19.2165          20.88
# 9              633590                141263       20.077        41.7327
# 14             635100                145141      14.5305        24.6677
# 27             745760                146503      13.3947        33.0018
# 11              70840                147330      15.7983        42.0286
# 17            1172450                152853      13.7856        30.0601
# 30             105820                153076      12.2438        50.6928
# 15             339843                154778      13.4543        25.0243
# 10             266620                164077      20.1877        31.5388
# 26               6330                240274      9.45899        57.6126
# 8               14950                271793      8.67535        43.0124
#
# Item Tertiary_perc    Misc_perc Category
# 4          61.2963  2.76359e-06       C4
# 31         47.1395            0       C4
# 18         66.1183  1.42109e-14       C4
# 3          49.8589            0       C4
# 13         41.4476 -1.42109e-14       C4
# 16         39.3716            0       C4
# 22         40.5095 -3.30521e-06       C3
# 12         59.0267 -1.05155e-05       C3
# 19         52.4384            0       C3
# 29         50.9978  3.43487e-05       C3
# 25         44.7327            0       C3
# 6          34.1399 -1.42109e-14       C3
# 21         54.5132            0       C3
# 20         56.2627            0       C3
# 1          45.1259            0       C2
# 2          38.6144            0       C2
# 24         49.2877            0       C2
# 28         59.9035            0       C2
# 9          38.1903            0       C2
# 14         60.8018            0       C2
# 27         53.6035 -1.00487e-06       C2
# 11         42.1731 -1.02032e-05       C2
# 17         56.1544 -6.33574e-07       C2
# 30         37.0634            0       C1
# 15         61.5214 -2.07326e-06       C1
# 10         48.2735  2.51077e-06       C1
# 26         32.9284  6.81601e-05       C1
# 8          48.3122 -1.42109e-14       C1
#
# [28 rows x 39 columns]

# %% [markdown]
# <b>Find the top 3/4/5 sub-sectors</b>

# %%
# Find the contribution of sub sectors
sub_sec = ['Agriculture, forestry and fishing','Mining and quarrying','Manufacturing','Electricity, gas, water supply & other utility services',\
           'Construction','Trade, repair, hotels and restaurants','Transport, storage, communication & services related to broadcasting'\
           ,'Financial services','Real estate, ownership of dwelling & professional services','Public administration','Other services','TOTAL GSVA at basic prices']

final = final_df1.groupby('Category')[sub_sec].sum()
# Calculating % contribution of sub-sectors by dividing by total gsva
for i in sub_sec:
    final[i]=final[i]/final[sub_sec[-1]] *100
cat= final.index

# Transposing for plotting for each category
final=final.T

# %% [markdown]
# <b>Plotting the contribution of the sub-sectors as a percentage of the GSDP of each category. </b>

# %%
# Here, we are finding top categories that contribute to approx. 80% of the GSDP of respective categories of states
# Also, plotting sub-sector wise contribution for each category
li=[]

for i in final.columns:
    sorted_ = pd.DataFrame(final.loc[:,i].sort_values(ascending=False).iloc[1:,])
    # finding the top 80 % contributors
    sorted_['Cum_sum'] = np.cumsum(sorted_,axis=0)
    print(sorted_.Cum_sum)
    res = list(filter(lambda i: i > 80.0, (sorted_.Cum_sum).tolist()))[0]
    li.append(sorted_.index[:(sorted_.Cum_sum).tolist().index(res)+1])
    
    # Plotting the figure
    plt.figure(figsize=(8,6))
    plt.title(i + ' - Sub-Sector wise contribution')
    y_pos = np.arange(len(sorted_.index))    
    plt.barh(y_pos, sorted_[i])
    plt.yticks(y_pos,sorted_.index)
    plt.savefig('perc_sub_' + str(i) + '.png')
    plt.show()
# Out:
# Item
# Manufacturing                                                            18.137165
# Agriculture, forestry and fishing                                        32.917863
# Trade, repair, hotels and restaurants                                    47.462926
# Real estate, ownership of dwelling & professional services               61.853914
# Construction                                                             73.505280
# Other services                                                           81.862082
# Transport, storage, communication & services related to broadcasting     89.149512
# Financial services                                                       93.143393
# Public administration                                                    96.979407
# Electricity, gas, water supply & other utility services                  99.229684
# Mining and quarrying                                                    100.000001
# Name: Cum_sum, dtype: float64
# Item
# Manufacturing                                                            19.243805
# Real estate, ownership of dwelling & professional services               36.294759
# Agriculture, forestry and fishing                                        52.050612
# Trade, repair, hotels and restaurants                                    63.405821
# Construction                                                             71.241378
# Other services                                                           78.277071
# Financial services                                                       85.014467
# Transport, storage, communication & services related to broadcasting     91.742530
# Public administration                                                    95.339844
# Electricity, gas, water supply & other utility services                  97.930788
# Mining and quarrying                                                    100.000000
# Name: Cum_sum, dtype: float64
# Item
# Agriculture, forestry and fishing                                       22.597394
# Manufacturing                                                           36.828251
# Trade, repair, hotels and restaurants                                   47.663025
# Real estate, ownership of dwelling & professional services              57.918684
# Construction                                                            67.137572
# Other services                                                          74.578170
# Mining and quarrying                                                    81.892695
# Transport, storage, communication & services related to broadcasting    88.024094
# Public administration                                                   93.539087
# Financial services                                                      96.843158
# Electricity, gas, water supply & other utility services                 99.999998
# Name: Cum_sum, dtype: float64
# Item
# Agriculture, forestry and fishing                                        25.813440
# Trade, repair, hotels and restaurants                                    38.318443
# Manufacturing                                                            49.687100
# Real estate, ownership of dwelling & professional services               60.687450
# Construction                                                             71.050102
# Transport, storage, communication & services related to broadcasting     78.417084
# Other services                                                           85.632655
# Public administration                                                    91.768833
# Financial services                                                       95.265143
# Mining and quarrying                                                     98.038906
# Electricity, gas, water supply & other utility services                 100.000000
# Name: Cum_sum, dtype: float64

# %%
# printing the top 80% contributors for GSDP category wise
for i in range(4):
    print('TOP CONTRIBUTORS FOR C'+str(i+1))
    print(list(li[i]))
    print()
# Out:
# TOP CONTRIBUTORS FOR C1
# ['Manufacturing', 'Agriculture, forestry and fishing', 'Trade, repair, hotels and restaurants', 'Real estate, ownership of dwelling & professional services', 'Construction', 'Other services']
#
# TOP CONTRIBUTORS FOR C2
# ['Manufacturing', 'Real estate, ownership of dwelling & professional services', 'Agriculture, forestry and fishing', 'Trade, repair, hotels and restaurants', 'Construction', 'Other services', 'Financial services']
#
# TOP CONTRIBUTORS FOR C3
# ['Agriculture, forestry and fishing', 'Manufacturing', 'Trade, repair, hotels and restaurants', 'Real estate, ownership of dwelling & professional services', 'Construction', 'Other services', 'Mining and quarrying']
#
# TOP CONTRIBUTORS FOR C4
# ['Agriculture, forestry and fishing', 'Trade, repair, hotels and restaurants', 'Manufacturing', 'Real estate, ownership of dwelling & professional services', 'Construction', 'Transport, storage, communication & services related to broadcasting', 'Other services']

# %%
# It can be easily seen that C1,C2 states have mix % of Manufacturing, Agriculture, Trade, Real State and Construction as top
# contributors.
# This is lacking in C3 and C4 states

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------
# ##                                                               END
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Part II

# %% [markdown]
# <b>Preparing and Manipulating data for easy merging</b>

# %%
# Reading the drop_out data
drop_out= pd.read_csv('rs_session243_au570_1.1.csv')
drop_out = drop_out[['Level of Education - State','Primary - 2014-2015.1', 'Upper Primary - 2014-2015','Secondary - 2014-2015']]

# Renaming to State and removing .1 from Primary - 2014-2015 column name
drop_out.columns=['State','Primary - 2014-2015','Upper Primary - 2014-2015','Secondary - 2014-2015']
drop_out
# Out:
#                    State  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0          A & N Islands                 0.51                       1.69
# 1         Andhra Pradesh                 6.72                       5.20
# 2      Arunachal Pradesh                10.82                       6.71
# 3                  Assam                15.36                      10.51
# 4                  Bihar                  NaN                       4.08
# 5             Chandigarh                  NaN                       0.44
# 6            Chhatisgarh                 2.91                       5.85
# 7   Dadra & Nagar Haveli                 1.47                       4.02
# 8            Daman & Diu                 1.11                       3.11
# 9                  Delhi                  NaN                       0.76
# 10                   Goa                 0.73                       0.07
# 11               Gujarat                 0.89                       6.41
# 12               Haryana                 5.61                       5.81
# 13      Himachal Pradesh                 0.64                       0.87
# 14     Jammu and Kashmir                 6.79                       5.44
# 15             Jharkhand                 5.48                       8.99
# 16             Karnataka                 2.02                       3.85
# 17                Kerala                  NaN                        NaN
# 18           Lakshadweep                  NaN                       2.78
# 19        Madhya Pradesh                 6.59                       9.20
# 20           Maharashtra                 1.26                       1.79
# 21               Manipur                 9.66                       4.20
# 22             Meghalaya                 9.46                       6.52
# 23               Mizoram                10.10                       4.78
# 24              Nagaland                 5.61                       7.92
# 25                Odisha                 2.86                       3.81
# 26            Puducherry                 0.37                       0.56
# 27                Punjab                 3.05                       3.22
# 28             Rajasthan                 5.02                       3.07
# 29                Sikkim                 2.27                       1.57
# 30            Tamil Nadu                  NaN                        NaN
# 31             Telangana                 2.08                       2.30
# 32               Tripura                 1.28                       1.99
# 33         Uttar Pradesh                 8.58                       2.70
# 34            Uttrakhand                 4.04                       1.19
# 35           West Bengal                 1.47                       4.30
# 36             All India                 4.13                       4.03
#
#     Secondary - 2014-2015
# 0                   9.870
# 1                  15.710
# 2                  17.110
# 3                  27.060
# 4                  25.900
# 5                     NaN
# 6                  21.260
# 7                  16.770
# 8                  32.270
# 9                  11.810
# 10                 11.150
# 11                 25.040
# 12                 15.890
# 13                  6.070
# 14                 17.280
# 15                 24.000
# 16                 26.180
# 17                 12.320
# 18                  6.763
# 19                 24.770
# 20                 12.870
# 21                 14.380
# 22                 20.520
# 23                 21.880
# 24                 18.230
# 25                 29.560
# 26                 12.190
# 27                  8.860
# 28                 13.480
# 29                 15.890
# 30                  8.100
# 31                 15.530
# 32                 28.420
# 33                 10.220
# 34                 10.400
# 35                 17.800
# 36                 17.060

# %%
# Changing the relevant differences in State names(not touching Union Territories, as they are not present in I-B data)
drop_out.loc[34,'State']='Uttarakhand'
drop_out.loc[6,'State']='Chhattisgarh'
final_df1['State']=final_df1['State'].str.replace('_',' ')
final_df1.loc[12,'State']='Jammu and Kashmir'

# Merging the Dataframes on State
drop_out_final=pd.merge(final_df1, drop_out, how='left', on=['State'])
drop_out_final
# Out:
#                 State Agriculture, forestry and fishing        Crops  \
# 0               Bihar                           7951890      4688237
# 1       Uttar Pradesh                          25097754     16215212
# 2             Manipur                            383140       226583
# 3               Assam                           3855548      2890544
# 4           Jharkhand                           3211065      2094466
# 5      Madhya Pradesh                          16235647     13216013
# 6              Odisha                           6422978      4382636
# 7   Jammu and Kashmir                           1586705       949424
# 8           Meghalaya                            366521       223330
# 9             Tripura                            799825       397591
# 10          Rajasthan                          15044394      7673441
# 11       Chhattisgarh                           3948847      2613371
# 12           Nagaland                            607897       375825
# 13            Mizoram                            217010       116609
# 14     Andhra Pradesh                          14819416      7893514
# 15  Arunachal Pradesh                            686117       415520
# 16             Punjab                           9285716      5690972
# 17          Telangana                           7591501      4162493
# 18            Gujarat                         1.377e+07  9.67109e+06
# 19          Karnataka                          11219422      8157179
# 20         Tamil Nadu                          13064238      7297820
# 21   Himachal Pradesh                           1514981       853758
# 22        Maharashtra                          16475655     10435121
# 23        Uttarakhand                       1.60142e+06       866146
# 24             Kerala                           5930617      3070386
# 25            Haryana                       8.01524e+06  4.63673e+06
# 26             Sikkim                            137447       114976
# 27                Goa                            308507       140421
#
#       Livestock Forestry and logging Fishing and aquaculture  \
# 0       2060296               550132                  653224
# 1       7096876              1404936                  380730
# 2         75483                45831                   35243
# 3        173478               261987                  529539
# 4        562503               445149                  108947
# 5       1932769               965588                  121277
# 6        788243               791463                  460636
# 7        433133               168093                   36055
# 8         72442                61166                    9583
# 9         88176               145096                  168961
# 10      5356257              1956660                   58036
# 11       352208               597785                  385483
# 12       123800                99802                    8470
# 13        45590                47763                    7048
# 14      4309078               346160                 2270664
# 15        38387               224017                    8193
# 16      2638842               848245                  107657
# 17      2951299               210741                  266968
# 18  2.69891e+06               761616                  638357
# 19      1868771               693082                  500390
# 20      4693361               392705                  680352
# 21       110304               540950                    9968
# 22      3972829              1592564                  475141
# 23       391188               339293                    4796
# 24      1656104               499808                  704319
# 25  2.91617e+06               352254                  110080
# 26        17338                 4529                     604
# 27        30141                15744                  122201
#
#    Mining and quarrying      Primary Manufacturing  \
# 0                 68107      8019997       2189965
# 1                901501     25999255      12261649
# 2                   NaN       383140         49501
# 3               1471149      5326697       2002936
# 4               2037289      5248354       4114148
# 5               1618373     17854020       4368833
# 6               2586328      9009306       5754229
# 7                 33621      1620326        893207
# 8                 84529       451050        433213
# 9                142391       942216        228625
# 10              4069385     19113780       6552580
# 11              2451970      6400817       4370593
# 12                 8280       616178         18346
# 13                 8588       225598          8479
# 14              1484300     16303716       4672266
# 15                30842       716959         26120
# 16                10354      9296070       4790341
# 17              1541853      9133354       6353711
# 18          2.11722e+06  1.58872e+07   2.40875e+07
# 19               846882     12066304      12953843
# 20               265536     13329774      18914794
# 21                33385      1548366       2543637
# 22              5282727     21758383      33660294
# 23               244549  1.84597e+06   5.86625e+06
# 24               558824      6489442       4273567
# 25                25186  8.04042e+06   7.75692e+06
# 26                 1329       138776        550697
# 27                 3622       312129       1177608
#
#    Electricity, gas, water supply & other utility services  ...  \
# 0                                              345168       ...
# 1                                             2030625       ...
# 2                                               27490       ...
# 3                                              296587       ...
# 4                                              337489       ...
# 5                                             1272905       ...
# 6                                              833067       ...
# 7                                              597421       ...
# 8                                               54473       ...
# 9                                               77870       ...
# 10                                            1122888       ...
# 11                                            1198438       ...
# 12                                              37944       ...
# 13                                             128365       ...
# 14                                            1151729       ...
# 15                                             113527       ...
# 16                                             911611       ...
# 17                                             716266       ...
# 18                                        3.40998e+06       ...
# 19                                            1425762       ...
# 20                                            1710379       ...
# 21                                             767268       ...
# 22                                            4334702       ...
# 23                                             433880       ...
# 24                                             482470       ...
# 25                                        1.10192e+06       ...
# 26                                             212499       ...
# 27                                             204110       ...
#
#    Population ('00) Per Capita GSDP (Rs.) Primary_perc Secondary_perc  \
# 0           1101240                 33954       22.164        16.5398
# 1           2109940                 49450      26.6613        26.1993
# 2             30873                 58442      21.5169        12.3648
# 3            326780                 60621      28.5355        21.6056
# 4            349660                 62091      26.7457        31.8066
# 5            765180                 62989      38.7994         21.829
# 6            435220                 73979      29.7777        29.7128
# 7            132390                 75840      17.0386        23.9347
# 8             32020                 76228      19.6995         27.862
# 9             38350                 77358      32.3639        16.6383
# 10           721610                 84837       32.865        22.4023
# 11           270530                 86860      28.7956        37.0645
# 12            20550                 89607      33.8281        11.6586
# 13            11833                 97687      19.9065        23.8308
# 14           501510                104977      33.3918        21.4824
# 15            14870                112718      43.8161        17.5695
# 16           290673                126606      27.4068        23.3054
# 17           367660                139035      19.2165          20.88
# 18           633590                141263       20.077        41.7327
# 19           635100                145141      14.5305        24.6677
# 20           745760                146503      13.3947        33.0018
# 21            70840                147330      15.7983        42.0286
# 22          1172450                152853      13.7856        30.0601
# 23           105820                153076      12.2438        50.6928
# 24           339843                154778      13.4543        25.0243
# 25           266620                164077      20.1877        31.5388
# 26             6330                240274      9.45899        57.6126
# 27            14950                271793      8.67535        43.0124
#
#    Tertiary_perc    Misc_perc Category Primary - 2014-2015  \
# 0        61.2963  2.76359e-06       C4                 NaN
# 1        47.1395            0       C4                8.58
# 2        66.1183  1.42109e-14       C4                9.66
# 3        49.8589            0       C4               15.36
# 4        41.4476 -1.42109e-14       C4                5.48
# 5        39.3716            0       C4                6.59
# 6        40.5095 -3.30521e-06       C3                2.86
# 7        59.0267 -1.05155e-05       C3                6.79
# 8        52.4384            0       C3                9.46
# 9        50.9978  3.43487e-05       C3                1.28
# 10       44.7327            0       C3                5.02
# 11       34.1399 -1.42109e-14       C3                2.91
# 12       54.5132            0       C3                5.61
# 13       56.2627            0       C3               10.10
# 14       45.1259            0       C2                6.72
# 15       38.6144            0       C2               10.82
# 16       49.2877            0       C2                3.05
# 17       59.9035            0       C2                2.08
# 18       38.1903            0       C2                0.89
# 19       60.8018            0       C2                2.02
# 20       53.6035 -1.00487e-06       C2                 NaN
# 21       42.1731 -1.02032e-05       C2                0.64
# 22       56.1544 -6.33574e-07       C2                1.26
# 23       37.0634            0       C1                4.04
# 24       61.5214 -2.07326e-06       C1                 NaN
# 25       48.2735  2.51077e-06       C1                5.61
# 26       32.9284  6.81601e-05       C1                2.27
# 27       48.3122 -1.42109e-14       C1                0.73
#
#    Upper Primary - 2014-2015 Secondary - 2014-2015
# 0                       4.08                 25.90
# 1                       2.70                 10.22
# 2                       4.20                 14.38
# 3                      10.51                 27.06
# 4                       8.99                 24.00
# 5                       9.20                 24.77
# 6                       3.81                 29.56
# 7                       5.44                 17.28
# 8                       6.52                 20.52
# 9                       1.99                 28.42
# 10                      3.07                 13.48
# 11                      5.85                 21.26
# 12                      7.92                 18.23
# 13                      4.78                 21.88
# 14                      5.20                 15.71
# 15                      6.71                 17.11
# 16                      3.22                  8.86
# 17                      2.30                 15.53
# 18                      6.41                 25.04
# 19                      3.85                 26.18
# 20                       NaN                  8.10
# 21                      0.87                  6.07
# 22                      1.79                 12.87
# 23                      1.19                 10.40
# 24                       NaN                 12.32
# 25                      5.81                 15.89
# 26                      1.57                 15.89
# 27                      0.07                 11.15
#
# [28 rows x 42 columns]

# %% [markdown]
# <b>Correlation of GDP per capita with dropout rates in education</b>

# %%
#Drawing Scatter plots with regression line for observing the correlation of 'Per Capita GSDP (Rs.)' with dropout rates
sns.lmplot(x='Primary - 2014-2015',y='Per Capita GSDP (Rs.)',data=drop_out_final)
k=drop_out_final['Per Capita GSDP (Rs.)'].astype(np.float64)
print('correlation with Primary dropout ',drop_out_final['Primary - 2014-2015'].corr(k))
plt.savefig('corr_primary.png')
plt.show()
# Out:
# correlation with Primary dropout  -0.5599341853043037

# %%
sns.lmplot(x='Upper Primary - 2014-2015',y='Per Capita GSDP (Rs.)',data=drop_out_final)
print('correlation with Upper Primary dropout ',drop_out_final['Upper Primary - 2014-2015'].corr(k))
plt.savefig('corr_upper_primary.png')
plt.show()
# Out:
# correlation with Upper Primary dropout  -0.5456514875066955

# %%
sns.lmplot(x='Secondary - 2014-2015',y='Per Capita GSDP (Rs.)',data=drop_out_final)
print('correlation with Secondary dropout ',drop_out_final['Secondary - 2014-2015'].corr(k))
plt.savefig('corr_secondary.png')
plt.show()
# Out:
# correlation with Secondary dropout  -0.45935022406533166

# %%
# We can observe that dropout rates in each category are inversely correlated to per capita GSDP.
# Thus we can conclude that education is a key area to focus for preparing skilled population that can contribute to state GDP.
